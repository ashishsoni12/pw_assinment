# %% [markdown]
# Theoritical

# %% [markdown]
# Q1. What is the difference between a function and a method in Python?
#
# Ans:
# A function is a block of code that performs a task and can be called independently.
#
# A method is a function that is associated with an object (usually a class or data type).
#
# method = function + object.

# %% [markdown]
# **Q2. Explain the concept of function arguments and parameters in Python.**
#
# Parameters are the placeholders used in the function definition.
#
# Arguments are the real values you pass when calling the function.

# %% [markdown]
# **Q3. What are the different ways to define and call a function in Python?**
#
# def say_hello():
#     print("Hello!")
#
# say_hello()
#
# Other ways to define:
#
# Using default parameters
#
# Using lambda functions

# %% [markdown]
# **Q4. What is the purpose of the return statement in a Python function?**
#
# It sends back a value from the function to the caller.
#
# It ends the function.

# %% [markdown]
# **Q5. What are iterators in Python and how do they differ from iterables?**
#
#
# An iterable is anything you can loop over (like a list or string).
#
# An iterator is an object with a __next__() method that gives the next item.
#
# lst = [1, 2, 3]       # iterable
# it = iter(lst)        # iterator
# print(next(it))       # 1
# print(next(it))       # 2

# %% [markdown]
# **Q6. Explain the concept of generators in Python and how they are defined.**
#
# Generators are like functions but use yield instead of return.
#
# They give one value at a time and remember their state.
#
# def my_gen():
#     yield 1
#     yield 2
#
# g = my_gen()
# print(next(g))  # 1
# print(next(g))  # 2

# %% [markdown]
# **Q7. What are the advantages of using generators over regular functions?**
# Memory efficient: They don’t store all values in memory.
#
# Faster for large data: They generate data on-the-fly.
#
# Pause and resume: They remember where they left off.

# %% [markdown]
# **Q8. What is a lambda function in Python and when is it typically used?**
#
# A lambda is a small anonymous function (no name).
#
# Used for short, simple operations (often with map(), filter()).
#
# square = lambda x: x * x
# print(square(5))  # 25

# %% [markdown]
# > Add blockquote

# %% [markdown]
# **Q9. Explain the purpose and usage of the map() function in Python.**
#
# map() applies a function to every item in an iterable (like a list).
#
# nums = [1, 2, 3]
# squares = list(map(lambda x: x * x, nums))
# print(squares)  # [1, 4, 9]

# %% [markdown]
#  Q10.What is the difference between map(), reduce(), and filter()?
#
# Function	         Purpose	                 Example Use
# map()	    Applies function to all items	  Convert Celsius to Fahrenheit
# filter()	Filters items using condition	  Keep only even numbers
# reduce()	Reduces list to single value	  Add all numbers together

# %% [markdown]
# Q11. Internal Mechanism for reduce() with list [47, 11, 42, 13]
#
# ![q12.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Practical Questions

# %%
# 1. Write a Python function that takes a list of numbers as input and returns the sum of all even numbers in
# the list.

def fun(ls):
   z= lambda x: x%2==0
   return sum(filter(z,ls))
ls=list(map(int,input().split()))
print(fun(ls))
# Out:
# 1 2 4 6 7 9
# 12

# %%
#  2. Create a Python function that accepts a string and returns the reverse of that string.

def func(s):
  return s[::-1]
s=input("enter the string-> ")
print(func(s))
# Out:
# enter the string-> ashish
# hsihsa

# %%
#  3. Implement a Python function that takes a list of integers and returns a new list containing the squares of
# each number.
def func(ls):
  return list(map(lambda x:x**2,ls))
ls=list(map(int,input().split()))
print(func(ls))
# Out:
# 1 2 3 4 5 6 7 8
# [1, 4, 9, 16, 25, 36, 49, 64]

# %%
# 4. Write a Python function that checks if a given number is prime or not from 1 to 200
for i in range(1,201):
  if i>1:
    for j in range(2,i):
      if i%j==0:
        print(f"No {i} is not prime")
        break
    else:
      print(f"No {i} is prime")
# Out:
# No 2 is prime
# No 3 is prime
# No 4 is not prime
# No 5 is prime
# No 6 is not prime
# No 7 is prime
# No 8 is not prime
# No 9 is not prime
# No 10 is not prime
# No 11 is prime
# No 12 is not prime
# No 13 is prime
# No 14 is not prime
# No 15 is not prime
# No 16 is not prime
# No 17 is prime
# No 18 is not prime
# No 19 is prime
# No 20 is not prime
# No 21 is not prime
# No 22 is not prime
# No 23 is prime
# No 24 is not prime
# No 25 is not prime
# No 26 is not prime
# No 27 is not prime
# No 28 is not prime
# No 29 is prime
# No 30 is not prime
# No 31 is prime
# No 32 is not prime
# No 33 is not prime
# No 34 is not prime
# No 35 is not prime
# No 36 is not prime
# No 37 is prime
# No 38 is not prime
# No 39 is not prime
# No 40 is not prime
# No 41 is prime
# No 42 is not prime
# No 43 is prime
# No 44 is not prime
# No 45 is not prime
# No 46 is not prime
# No 47 is prime
# No 48 is not prime
# No 49 is not prime
# No 50 is not prime
# No 51 is not prime
# ...

# %%
# 5. Create an iterator class in Python that generates the Fibonacci sequence up to a specified number of
#terms

class fib:
  def __init__(self,max_terms):
    self.max_terms=max_terms
    self.a=0
    self.b=1
    self.count=0
  def __iter__(self):
    return self
  def __next__(self):
        if self.count >= self.max_terms:
            raise StopIteration
        if self.count == 0:
            self.count += 1
            return 0
        elif self.count == 1:
            self.count += 1
            return 1
        else:
            self.a, self.b = self.b, self.a + self.b
            self.count += 1
            return self.b
max_terms = int(input("Enter the number of terms: "))
fib_gen = fib(max_terms)
for num in fib_gen:
  print(num)
# Out:
# Enter the number of terms: 5
# 0
# 1
# 1
# 2
# 3

# %%
 #6. Write a generator function in Python that yields the powers of 2 up to a given exponent

def gen(x):
   for t in range(x+1):
    yield t**2
x=int(input("enter the exponent-> "))
for i in gen(x):
  print(i)
# Out:
# enter the exponent-> 5
# 0
# 1
# 4
# 9
# 16
# 25

# %%
# 7. Implement a generator function that reads a file line by line and yields each line as a string
def read_file_line_by_line(file_path):
    with open(file_path, 'r') as file:
        for line in file:
            yield line.rstrip('\n')  # remove newline character at the end
for line in read_file_line_by_line("sample.txt"):
    print(line)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-c561c4ed8276> in <cell line: 0>()
#       4         for line in file:
#       5             yield line.rstrip('\n')  # remove newline character at the end
# ----> 6 for line in read_file_line_by_line("sample.txt"):
#       7     print(line)
#
# <ipython-input-6-c561c4ed8276> in read_file_line_by_line(file_path)
#       1 # 7. Implement a generator function that reads a file line by line and yields each line as a string
#       2 def read_file_line_by_line(file_path):
# ----> 3     with open(file_path, 'r') as file:
#       4         for line in file:
#       5             yield line.rstrip('\n')  # remove newline character at the end
#
# FileNotFoundError: [Errno 2] No such file or directory: 'sample.txt'

# %%
 #8. Use a lambda function in Python to sort a list of tuples based on the second element of each tuple
data = [(1, 4), (3, 1), (5, 2), (2, 3)]

# Sort based on the second element of each tuple
sorted_data = sorted(data, key=lambda x: x[1])

print(sorted_data)
# Out:
# [(3, 1), (5, 2), (2, 3), (1, 4)]

# %%
 #9. Write a Python program that uses `map()` to convert a list of temperatures from Celsius to Fahrenheit
 # List of temperatures in Celsius
celsius_temps = [0, 10, 20, 30, 40]

# Convert to Fahrenheit using map() and a lambda function
fahrenheit_temps = list(map(lambda c: (c * 9/5) + 32, celsius_temps))

# Print the result
print("Celsius:", celsius_temps)
print("Fahrenheit:", fahrenheit_temps)
# Out:
# Celsius: [0, 10, 20, 30, 40]
# Fahrenheit: [32.0, 50.0, 68.0, 86.0, 104.0]

# %%
# 10. Create a Python program that uses `filter()` to remove all the vowels from a given string
def remove_vowels(input_str):
    vowels = 'aeiouAEIOU'
    return ''.join(filter(lambda char: char not in vowels, input_str))

# Example usage
text = "Hello, World!"
result = remove_vowels(text)

print("Original:", text)
print("Without vowels:", result)
# Out:
# Original: Hello, World!
# Without vowels: Hll, Wrld!
